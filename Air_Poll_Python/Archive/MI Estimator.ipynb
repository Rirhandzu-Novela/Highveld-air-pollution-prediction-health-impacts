# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('SecundaIMMIPM10.csv', sep =';', header=0, index_col=0)
values = df.values

# %%
df.dropna(how='all')
# Out:
#                      Spm2.5   Sso2    Sno2    Sno    Snox     So3    Sco  \
# date
# 2009/01/01 1:00    9.570000  3.400  15.990  1.230   2.540  27.990  0.040
# 2009/01/01 2:00    4.890000  3.450  15.990  1.070   2.690  27.990  0.030
# 2009/01/01 3:00   11.130000  3.130  15.990  1.610   8.110  27.990  0.040
# 2009/01/01 4:00    9.180000  4.410  15.990  1.430  10.280  27.990  0.030
# 2009/01/01 5:00    6.780000  3.820  15.990  1.470   7.020  27.990  0.020
# ...                     ...    ...     ...    ...     ...     ...    ...
# 2018/12/31 18:00  10.436561  0.433   7.178  1.050   8.227   6.091  0.069
# 2018/12/31 19:00  10.436571  0.397   7.475  1.025   8.500   6.458  0.084
# 2018/12/31 20:00  10.436581  0.407   7.979  1.064   9.043   7.140  0.098
# 2018/12/31 21:00  10.436590  0.355   7.876  1.017   8.893   6.351  0.097
# 2018/12/31 22:00  10.436600  0.350   8.440  1.241   9.680   5.822  0.092
#
#                    Sws     Swd  Stemp  ...      no     nox      o3     co  \
# ...

# %%
X = values[:,:-1]

# %%
Y = values[:,-1]

# %%
from sklearn.feature_selection import mutual_info_regression
mi = mutual_info_regression(X, Y)
mi /= np.max(mi)

# %%
print(mi)
# Out:
# [1.         0.14314356 0.33141362 0.23843598 0.24893865 0.20366003
#  0.31136958 0.21089188 0.12439541 0.07487585 0.04697894 0.16887814
#  0.19318399 0.17027397 0.1275006  0.11552062 0.13204299 0.12838643
#  0.10404505 0.16071234 0.13947605 0.085172   0.06463185 0.04323854
#  0.09052956 0.39198833 0.38455534 0.11105957 0.09218127 0.09302566
#  0.07935186 0.09021033 0.11819869 0.06646039 0.02817188 0.04520931
#  0.0491721  0.12549276 0.20924605 0.22747015 0.11906558 0.17056451
#  0.17295386 0.15441113 0.09428208 0.15299573 0.07759685 0.0650822
#  0.04868585 0.06239599 0.07294956 0.18434331 0.17685574 0.08986455
#  0.10806282 0.12645205 0.11959811 0.05034975 0.0952884  0.05515336
#  0.02923128 0.04458567 0.03047427 0.05768325]

# %%
def plot_mi_scores(scores):
    scores = scores.sort_values(ascending=True)
    width = np.arange(len(scores))
    ticks = list(scores.index)
    plt.barh(width, scores)
    plt.yticks(width, ticks)
    plt.title("eMalahleni PM2.5 Mutual Information Scores")


plt.figure(dpi=100, figsize=(8, 5))
plot_mi_scores(mi_scores)

# %%
mi.to_csv('MiePM2.5.csv', sep =';')

# %%
sns.lmplot(x = "PM10", y = "PM2.5", hue = "CO", data = df);

# %%
code credit: https://www.kaggle.com/code/ryanholbrook/mutual-information/tutorial
